# %% [markdown]
# YOUNESS MOUAD (20 132 250)
# EL MAHDI ZOUHAIR (20 132 241)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

class GestionDonnees:
    def __init__(self, bruit):
        """
            nb_entrain: specifier le nombre de données qu'on veut utiliser pour l'entrainement
            nb_test: specifier le nombre de données qu'on veut utiliser pour le test
            bruit: présence du bruit
        """
        self.nb_entrain = nb_entrain
        self.nb_test = nb_test
        self.bruit = bruit

    def generer_donnees(self):

        chemin_entrain = './data/train.csv'
        chemin_test = './data/test.csv'
        les_donnees_entrain = pd.read_csv(path, sep=',')
        les_donnees_test = pd.read_csv(path, sep=',')

        np.random.seed(self.nb_entrain)
        indices_entrain = np.random.rand(self.nb_train)
        indices_test = np.random.rand(self.nb_test)
